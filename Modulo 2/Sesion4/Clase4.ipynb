# %% [markdown]
# # Tidy DATA PANDAS

# %%
# Clase 4a
import pandas as pd
d={
    'pais':['Mexico','Colombia','Salvador'],
    '199':[744,37989,12000000],
    '200':[1200,48000,1400000]
}

# %%
df=pd.DataFrame(d)
df
# Out:
#        pais       199      200
# 0    Mexico       744     1200
# 1  Colombia     37989    48000
# 2  Salvador  12000000  1400000

# %% [markdown]
# # Agrupar datos

# %%
pd.melt(df,id_vars='pais',var_name='año',value_name='cuenta')
# Out:
#        pais  año    cuenta
# 0    Mexico  199       744
# 1  Colombia  199     37989
# 2  Salvador  199  12000000
# 3    Mexico  200      1200
# 4  Colombia  200     48000
# 5  Salvador  200   1400000

# %%
df_relinc=pd.read_csv('data/religion_income.csv')
df_relinc
# Out:
#                    religion  <10k  10-20k  20-30k  30-40k  40-50k  50-75k  \
# 0                  Agnostic    27      34      60      81      76     137
# 1                   Atheist    12      27      37      52      35      70
# 2                  Buddhist    27      21      30      34      33      58
# 3                  Catholic   418     617     732     670     638    1116
# 4                   refused    15      14      15      11      10      35
# 5          Evangelical Prot   575     869    1064     982     881    1486
# 6                     Hindu     1       9       7       9      11      34
# 7   Historically Black Prot   228     244     236     238     197     223
# 8         Jehovah's Witness    20      27      24      24      21      30
# 9                    Jewish    19      19      25      25      30      95
# 10            Mainline Prot   289     495     619     655     651    1107
# 11                   Mormon    29      40      48      51      56     112
# ...

# %%
df_relinc.tail()
# Out:
#                  religion  <10k  10-20k  20-30k  30-40k  40-50k  50-75k  \
# 13               Orthodox    13      17      23      32      32      47
# 14        Other Christian     9       7      11      13      13      14
# 15           Other Faiths    20      33      40      46      49      63
# 16  Other World Religions     5       2       3       4       2       7
# 17           Unaffiliated   217     299     374     365     341     528
#
#     75-100k  100-150k  >150k  refused
# 13       38        42     46       73
# 14       18        14     12       18
# 15       46        40     41       71
# 16        3         4      4        8
# 17      407       321    258      597

# %%
pd.melt(df_relinc, id_vars='religion',var_name='income',value_name='frecuency')
# Out:
#                   religion   income  frecuency
# 0                 Agnostic     <10k         27
# 1                  Atheist     <10k         12
# 2                 Buddhist     <10k         27
# 3                 Catholic     <10k        418
# 4                  refused     <10k         15
# ..                     ...      ...        ...
# 175               Orthodox  refused         73
# 176        Other Christian  refused         18
# 177           Other Faiths  refused         71
# 178  Other World Religions  refused          8
# 179           Unaffiliated  refused        597
#
# [180 rows x 3 columns]

# %%
wider_to_long=pd.read_csv('data\wider.csv')
wider_to_long.head()#primeros 5 elementos
# Out:
#    Unnamed: 0        pais  anio       tipo    cuenta
# 0           1  Afganistán  1999      casos       745
# 1           2  Afganistán  1999  población  19987071
# 2           3  Afganistán  2000      casos      2666
# 3           4  Afganistán  2000  población  20595360
# 4           5      Brasil  1999      casos     37737

# %%
wider_to_long.drop(columns=['Unnamed: 0'])#eliminar columnar que no se van a usar, parametro inplace=True, SOBRESCROBE EL DATAFrameb
# Out:
#           pais  anio       tipo      cuenta
# 0   Afganistán  1999      casos         745
# 1   Afganistán  1999  población    19987071
# 2   Afganistán  2000      casos        2666
# 3   Afganistán  2000  población    20595360
# 4       Brasil  1999      casos       37737
# 5       Brasil  1999  población   172006362
# 6       Brasil  2000      casos       80488
# 7       Brasil  2000  población   174504898
# 8        China  1999      casos      212258
# 9        China  1999  población  1272915272
# 10       China  2000      casos      213766
# 11       China  2000  población  1280428583

# %% [markdown]
# Si se tienen muchos valores repetidos, se pueden agrupar los valores

# %%
wider_to_long.pivot_table(index=['pais','anio',columns='tipo'])
