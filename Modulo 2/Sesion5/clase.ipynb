# %% [markdown]
# # Limpieza de datos

# %%
  import pandas as pd
  import numpy as np
  import datetime
  import chardet
  import seaborn as sns
  import matplotlib

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Using cached scipy-1.8.1-cp310-cp310-win_amd64.whl (36.9 MB)
# ...
#   Using cached matplotlib-3.5.2-cp310-cp310-win_amd64.whl (7.2 MB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached kiwisolver-1.4.3-cp310-cp310-win_amd64.whl (55 kB)
# ...
#   Using cached fonttools-4.33.3-py3-none-any.whl (930 kB)
# ...
#   Using cached Pillow-9.1.1-cp310-cp310-win_amd64.whl (3.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
derrumbes=pd.read_csv('data\derrumbes.csv')

# %%
derrumbes.info()  ## da informacion sobre la base
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1693 non-null   int64
#  1   date                  1690 non-null   object
#  2   time                  629 non-null    object
#  3   continent_code        164 non-null    object
#  4   country_name          1693 non-null   object
#  5   country_code          1693 non-null   object
#  6   state/province        1692 non-null   object
#  7   population            1693 non-null   int64
#  8   city/town             1689 non-null   object
#  9   distance              1692 non-null   float64
#  10  location_description  551 non-null    object
#  11  latitude              1692 non-null   float64
#  12  longitude             1692 non-null   float64
#  13  geolocation           1692 non-null   object
#  14  hazard_type           1693 non-null   object
# ...

# %% [markdown]
# para usar variables de tiempo se debe convertir los string a variables temporales
# En el formato tipo 'objeto' no deja usar las variables de tiempo, por lo que se debe convertir a tipo 'tiempo'

# %%
derrumbes['date']
# Out:
# 0        3/2/07
# 1       3/22/07
# 2        4/6/07
# 3       4/14/07
# 4       4/15/07
#          ...
# 1688    12/7/15
# 1689    2/22/16
# 1690    2/23/16
# 1691    2/26/16
# 1692     3/2/16
# Name: date, Length: 1693, dtype: object

# %% [markdown]
# Para tranformar la variable se usa el metodo de `to_datetime()`

# %%
derrumbes['datetime2']=pd.to_datetime(derrumbes['date'])

# %%
derrumbes.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ... hazard_type  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...   Landslide
# 1           Ohio       17288  New Philadelphia   3.33522  ...   Landslide
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...   Landslide
# 3         Quebec       42786       Châteauguay   2.98682  ...   Landslide
# 4       Kentucky        6903         Pikeville   5.66542  ...   Landslide
#
#        landslide_type  landslide_size   trigger storm_name injuries  \
# ...

# %%
derrumbes['datetime2'].dt.month
# Out:
# 0        3.0
# 1        3.0
# 2        4.0
# 3        4.0
# 4        4.0
#         ...
# 1688    12.0
# 1689     2.0
# 1690     2.0
# 1691     2.0
# 1692     3.0
# Name: datetime2, Length: 1693, dtype: float64

# %%
derrumbes['datetime2'].dt.day
# Out:
# 0        2.0
# 1       22.0
# 2        6.0
# 3       14.0
# 4       15.0
#         ...
# 1688     7.0
# 1689    22.0
# 1690    23.0
# 1691    26.0
# 1692     2.0
# Name: datetime2, Length: 1693, dtype: float64

# %%
derrumbes['datetime2'].dt.day.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\eugen\Documents\G17 DATA\Modulo 2\Sesion5\clase.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/eugen/Documents/G17%20DATA/Modulo%202/Sesion5/clase.ipynb#ch0000015?line=0'>1</a> derrumbes['datetime2'].dt.day.plot(kind='bar')
#
# File c:\Users\eugen\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:892, in PlotAccessor.__call__(self, *args, **kwargs)
#     <a href='file:///c%3A/Users/eugen/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=890'>891</a> def __call__(self, *args, **kwargs):
# --> <a href='file:///c%3A/Users/eugen/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=891'>892</a>     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
# ...

# %%
terremotos=pd.read_csv('data/terremotos.csv')
cuentas=pd.read_csv('data/accounts.csv')

# %%
pd.to_datetime(cuentas['date_opened'], infer_datetime_format=True)
# Out:
# 0    2003-10-19
# 1    2018-10-05
# 2    2008-07-29
# 3    2005-06-09
# 4    2012-03-31
#         ...
# 93   2004-02-20
# 94   2000-09-16
# 95   2007-04-29
# 96   2014-05-28
# 97   2007-10-14
# Name: date_opened, Length: 98, dtype: datetime64[ns]

# %% [markdown]
# Remplazar caracteres

# %%
adult=pd.read_csv('data/adult.csv')

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# Los errores de datos como en columnas `39`
# Para elininar espacions vacions o un caracter especial

# %%
adult.columns=adult.columns.str.strip()

# %%
adult.rename(columns={
    ' Male':'Male'
})
# Out:
#        39          State-gov   77516    Bachelors  13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 1      38            Private  215646      HS-grad   9             Divorced
# 2      53            Private  234721         11th   7   Married-civ-spouse
# 3      28            Private  338409    Bachelors  13   Married-civ-spouse
# 4      37            Private  284582      Masters  14   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32555  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad   9              Widowed
# 32558  22            Private  201490      HS-grad   9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...
